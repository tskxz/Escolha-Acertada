# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://www.escolhaacertada.pt/pt-PT/Imoveis/-/-/-/-/-/-/-/-/-/-/-/-/0/0/20/1/1",
                headers={
                    'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'
                })
c = r.content

soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("div", {"class":"row"})

l = []
a = []
b = []
c = []
e = []
f = []

for i in all:
    d = {}
    price = soup.find_all("div", {"class":"price"})
    name = soup.find_all("div", {"class":"info"})
    i_list = soup.find_all("i", class_="icon-area")
    beds = soup.find_all("i", class_="icon-bedrooms")
    bath = soup.find_all("i", class_="icon-bathrooms")
    
for names in name:
    names = names.find_all("a", {"class":"trackevent"})
    names = names[0].text
    b.append(names)
    d["Imóvel"] = b
    
    
for prices in price:
    prices = prices.text
    prices = " ".join(prices.split())
    a.append(prices)
    d["Preço"] = a
    
for area in i_list:
    area = area.parent.text
    c.append(area)
    d["Área"] = c
    
for bed in beds:
    bed = bed.parent.text
    e.append(bed)
    d["Quartos"] = e
    
for baths in bath:
    baths = baths.parent.text
    f.append(baths)
    d["Casas de banhos"] = f
    
l.append(d)

# %%
import pandas
for i in l:
    #print(i)
    df = pandas.DataFrame.from_dict(i, orient='index')

# %%
df = df.transpose()

# %%
df = df[['Imóvel', 'Área', 'Quartos', 'Preço', 'Casas de banhos']]

# %%
df
# Out:
#                                                Imóvel       Área Quartos  \
# 0                               Escritório Matosinhos     45 m2       1
# 1                           Escritório Porto Boavista     40 m2       1
# 2                          Escritório junto ao Covelo     73 m2       1
# 3                                      Café nos Altos     53 m2       3
# 4           T1 lavra condominio fechado junto a praia     65 m2       1
# 5                        T1 duplex Rua da Restauração     60 m2       5
# 6                   T1+1 com varanda rua da Cedofeita    100 m2     None
# 7                                T3 Matosinhos Centro    100 m2     None
# 8                               T1 à Rotunda Boavista     62 m2     None
# 9   Loja com duas frentes com espaço exterior próx...    173 m2     None
# 10                           Escritório Montes Burgos    200 m2     None
# 11           Loja ou Armazém Porto Carolina Michaelis    240 m2     None
# 12                             Loja Centro Matosinhos    180 m2     None
# 13          Armazém -Leça do Balio saida da Via Norte    785 m2     None
# 14                               Arrendamento Armazém    690 m2     None
# 15                   Escritório Zona Industrial Porto    167 m2     None
# 16          Terreno com 9950 m2 São Mamede de Infesta         -     None
# 17                 Excelente Moradia V5 Leça do Balio    305 m2     None
# 18                   Escritório zona Industrial Porto    294 m2     None
# 19                               Arrendamento Terreno  1.000 m2     None
#
#                              Preço Casas de banhos
# 0               Arrendamento 350 €              -
# 1               Arrendamento 370 €              -
# 2               Arrendamento 500 €              -
# 3               Arrendamento 575 €              -
# 4   Arrendamento para férias 650 €              -
# 5               Arrendamento 650 €              1
# 6               Arrendamento 825 €              -
# 7               Arrendamento 850 €              -
# 8             Arrendamento 1.200 €              -
# 9             Arrendamento 1.450 €              -
# 10            Arrendamento 1.500 €              -
# 11            Arrendamento 1.550 €              -
# 12            Arrendamento 1.800 €              -
# 13            Arrendamento 2.150 €              -
# 14            Arrendamento 2.500 €              -
# 15            Arrendamento 2.550 €              -
# 16            Arrendamento 3.200 €              -
# 17            Arrendamento 3.200 €              -
# 18            Arrendamento 4.350 €            None
# 19            Arrendamento 5.000 €            None
